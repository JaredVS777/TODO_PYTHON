# %% [markdown]
# MATPLOTLIB INSTALACION

# %%
pip install -U matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -U pip
# Out:
# ...
#      ---------------------------------------- 2.1/2.1 MB 1.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 22.3.1
#     Uninstalling pip-22.3.1:
#       Successfully uninstalled pip-22.3.1
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
plt.plot([4,8,13,17,20],[54, 67, 98, 78, 45])
plt.show()

# %%
x=[2,4,6,5,42,543,5,3,73,64,42,97,63,76,68,12,3,25,87,124,421,3,6,9,8,9,124,23,19,8,75]
num_bins=6
n,bins,patches=plt.hist(x,num_bins,facecolor='green')
plt.show()

# %%
titanic=['Age']
num_bins=10
n,bins,patches=plt.hist(x,num_bins,facecolor='green')
plt.show()

# %%
import numpy as np
n = 12 
X = np.arange(n) 
Y1 = (1 - X / float(n)) * np.random.uniform(0.5, 1.0, n) 
Y2 = (1 - X / float(n)) * np.random.uniform(0.5, 1.0, n) 
plt.bar(X, +Y1, facecolor='#9999ff', edgecolor='white') 
plt.bar(X, -Y2, facecolor='#ff9999', edgecolor='white') 
for x, y in zip(X, Y1): 
    plt.text(x + 0.4, y + 0.05, '%.2f' % y, ha='center', va='bottom') 
    plt.ylim(-1.25, +1.25)

# %%
Z= np.random.uniform(0,1,20)
plt.pie(Z)
# Out:
# ([<matplotlib.patches.Wedge at 0x2b1af997760>,
# ...
#  [Text(1.0570638618795127, 0.304328756295508, ''),
#   Text(0.7496456304012682, 0.8050039930461745, ''),
#   Text(0.2511765221955038, 1.0709390060585953, ''),
#   Text(-0.13290412413745603, 1.091941616473727, ''),
#   Text(-0.5036980625280869, 0.9778999242281655, ''),
#   Text(-0.8535720860597584, 0.693840539244856, ''),
#   Text(-1.0360284233095987, 0.3696553882937824, ''),
#   Text(-1.0960259108175068, 0.0934194991244068, ''),
#   Text(-1.0801104739648975, -0.2082339166210077, ''),
#   Text(-0.898279572230621, -0.6348966924730138, ''),
#   Text(-0.5551767878196355, -0.9496203105801136, ''),
#   Text(-0.3054611353436301, -1.0567371928699116, ''),
#   Text(-0.24966131862233695, -1.0712932492944012, ''),
#   Text(-0.11149587592878638, -1.0943348069265058, ''),
#   Text(0.23244587677040085, -1.0751599482739487, ''),
#   Text(0.5479663113498139, -0.9537992040391305, ''),
#   Text(0.7761805648440143, -0.7794509161957711, ''),
# ...

# %%
n=titanic==['Age']
X=titanic[(titanic['Age']>=25) & (titanic['Age']<=30)].head()
Y1 = (1 - X / float(n)) * np.random.uniform(0.5, 1.0, n) 
Y2 = (1 - X / float(n)) * np.random.uniform(0.5, 1.0, n) 
plt.bar(X, +Y1, facecolor='#9999ff', edgecolor='white') 
plt.bar(X, -Y2, facecolor='#ff9999', edgecolor='white') 
for x, y in zip(X, Y1): 
    plt.text(x + 0.4, y + 0.05, '%.2f' % y, ha='center', va='bottom') 
    plt.ylim(-1.25, +1.25)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 n=titanic==['Age']
# ----> 2 X=titanic[(titanic['Age']>=25) & (titanic['Age']<=30)].head()
#       3 Y1 = (1 - X / float(n)) * np.random.uniform(0.5, 1.0, n)
#       4 Y2 = (1 - X / float(n)) * np.random.uniform(0.5, 1.0, n)
#
# TypeError: list indices must be integers or slices, not str
