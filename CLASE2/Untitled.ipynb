# %%
canasta = {'manzana','naranja','manzana','pera','naranja','banana'}
print(canasta)#muestra que se removieron los duplicados
{'pera','manzana','banana','naranja'}
'naranja' in canasta #verificacion 
True
'yerba' in canasta
False
# Out:
# {'pera', 'naranja', 'banana', 'manzana'}
# False

# %%
tel={'Alejandro':967881741, 'Joseph':999015826, 'Pablo':957686738, 'Alberto':988886745, 'Maria':957686431, 'Andy':967800038, 'Jefferson' : 96789583907 }
#falta

# %%
print(tel)
# Out:
# {'Alejandro': 967881741, 'Joseph': 999015826, 'Pablo': 957686738, 'Alberto': 988886745, 'Maria': 957686431, 'Andy': 967800038, 'Jefferson': 96789583907}

# %%
def funcion ():
    return ("hola")
funcion()
# Out:
# 'hola'

# %%
def mi_funcion(nombre, apellido):
    nombre_completo = nombre+apellido
    print(nombre_completo)
    
mi_funcion("Jared"," Valenzuela")
# Out:
# JaredValenzuela

# %%
def sum(n1,n2):
    resultado=9+7
    print(resultado)
sum("n1","n2")
# Out:
# 16

# %% [markdown]
# #  MANEJO DE ARCHIVOS

# %%
def creartxt():
    archi=open('datos.txt','w')
    archi.close()
def grabartxt():
    archi=open('datos.txt','a')
    archi.write('Linea 1\n')
    archi.write('Linea 2\n')
    archi.write('Linea 3\n')
    archi.close()
creartxt()
grabartxt()

def leertxt():
    archi=open('datos.txt','r')
    linea=archi.readline()
    while linea!="":
        print (linea)
        linea=archi.readline()
    archi.close

def leertxtenlista():
    archi=open('datos.txt','r')
    lineas=archi.readlines()
    print(lineas)
    archi.clse
leertxt()
leertxtenlista
# Out:
# Linea 1
#
# Linea 2
#
# Linea 3
# <function __main__.leertxtenlista()>

# %%
def leertxt():
    archi=open('datos.txt','r')
    linea=archi.readline()
    while linea!="":
        print (linea)
        linea=archi.readline()
    archi.close
leertxt()
# Out:
# Linea 1
#
# Linea 2
#
# Linea 3

# %%
leertxt()
# Out:
# Un hombre preso y condenado a muerte, decide contar lo sucedido desde su perspectiva. AsÃ­, relata cÃ³mo desde la infancia sentÃ­a una afinidad especial con los animales, por lo que de adulto tenÃ­a muchas mascotas: pÃ¡jaros, peces, un perro, conejos, un mono y un gato.
#
#
#
# Su gato, llamado PlutÃ³n, era su favorito y pasaban todo el tiempo juntos. Sin embargo, con los aÃ±os el carÃ¡cter del protagonista sin nombre fue empeorando, debido al consumo de alcohol, por lo que se convirtiÃ³ en un ser mezquino y agresivo.
#
#
#
# Un dÃ­a, de regreso de una de sus salidas de excesos, se encontrÃ³ con el gato y lo atacÃ³, arrancÃ¡ndole un ojo. Aunque el animal se recuperÃ³, quedÃ³ con ese espacio vacÃ­o y jamÃ¡s volviÃ³ a acercarse a su dueÃ±o. Esta actitud enfureciÃ³ aÃºn mÃ¡s al hombre, y llevado por su perversidad, lo colgÃ³ de un Ã¡rbol.
#
#
#
# ...

# %%
archi=open('datos.txt','r')

# %%
mensaje=archi.read()

# %%
print(mensaje)
archi.close
# Out:
# Un hombre preso y condenado a muerte, decide contar lo sucedido desde su perspectiva. AsÃ­, relata cÃ³mo desde la infancia sentÃ­a una afinidad especial con los animales, por lo que de adulto tenÃ­a muchas mascotas: pÃ¡jaros, peces, un perro, conejos, un mono y un gato.
#
# Su gato, llamado PlutÃ³n, era su favorito y pasaban todo el tiempo juntos. Sin embargo, con los aÃ±os el carÃ¡cter del protagonista sin nombre fue empeorando, debido al consumo de alcohol, por lo que se convirtiÃ³ en un ser mezquino y agresivo.
#
# Un dÃ­a, de regreso de una de sus salidas de excesos, se encontrÃ³ con el gato y lo atacÃ³, arrancÃ¡ndole un ojo. Aunque el animal se recuperÃ³, quedÃ³ con ese espacio vacÃ­o y jamÃ¡s volviÃ³ a acercarse a su dueÃ±o. Esta actitud enfureciÃ³ aÃºn mÃ¡s al hombre, y llevado por su perversidad, lo colgÃ³ de un Ã¡rbol.
#
# ...

# %%
frecuenciapalabras=[]

# %%
for w in mensaje:
    frecuenciapalabras.append(mensaje.count(w))

# %%
frecuenciapalabras
# Out:
# [3,
#  114,
#  343,
#  15,
#  155,
#  37,
#  12,
#  104,
#  186,
#  343,
#  45,
#  104,
#  186,
#  104,
#  155,
#  343,
#  19,
#  343,
#  79,
#  155,
#  114,
#  77,
#  186,
#  114,
#  177,
#  77,
#  155,
#  343,
#  177,
#  343,
#  37,
#  78,
#  186,
#  104,
#  65,
#  186,
#  29,
#  343,
#  77,
#  186,
#  79,
#  71,
#  77,
#  186,
#  343,
#  79,
#  155,
#  114,
#  65,
#  177,
#  104,
#  343,
#  84,
#  155,
#  343,
#  104,
#  78,
#  79,
#  186,
#  77,
#  71,
#  77,
#  155,
#  343,
#  77,
#  186,
#  104,
#  77,
#  186,
#  343,
#  104,
#  78,
#  343,
#  45,
#  186,
#  104,
#  104,
#  45,
#  186,
#  79,
#  65,
#  71,
#  14,
#  177,
#  18,
#  343,
#  3,
#  104,
#  56,
#  15,
#  29,
#  343,
#  104,
#  186,
#  84,
#  177,
#  65,
#  177,
#  343,
#  79,
#  56,
#  30,
#  37,
#  155,
#  343,
#  77,
#  186,
#  104,
#  77,
#  186,
#  343,
#  84,
#  177,
#  343,
#  71,
#  114,
#  8,
#  177,
#  114,
#  79,
#  71,
#  177,
#  343,
#  104,
#  186,
#  114,
#  65,
#  56,
#  15,
#  177,
#  343,
#  78,
# ...

# %%
#ejemplo
cadenaPalabras="hola a todos, esta es la clase de analisis"
listaPalabras=cadenaPalabras.split()
listaPalabras
# Out:
# ['hola', 'a', 'todos,', 'esta', 'es', 'la', 'clase', 'de', 'analisis']

# %%
print("Cadena\n"+mensaje+"\n")
print("Lista\n"+str(mensaje)+"\n")
print("frecuencia\n"+str(mensaje)+"\n")
print("pares\n"+str(list(zip(mensaje)))+"\n")
# Out:
# Cadena
# Un hombre preso y condenado a muerte, decide contar lo sucedido desde su perspectiva. AsÃ­, relata cÃ³mo desde la infancia sentÃ­a una afinidad especial con los animales, por lo que de adulto tenÃ­a muchas mascotas: pÃ¡jaros, peces, un perro, conejos, un mono y un gato.
#
# Su gato, llamado PlutÃ³n, era su favorito y pasaban todo el tiempo juntos. Sin embargo, con los aÃ±os el carÃ¡cter del protagonista sin nombre fue empeorando, debido al consumo de alcohol, por lo que se convirtiÃ³ en un ser mezquino y agresivo.
#
# Un dÃ­a, de regreso de una de sus salidas de excesos, se encontrÃ³ con el gato y lo atacÃ³, arrancÃ¡ndole un ojo. Aunque el animal se recuperÃ³, quedÃ³ con ese espacio vacÃ­o y jamÃ¡s volviÃ³ a acercarse a su dueÃ±o. Esta actitud enfureciÃ³ aÃºn mÃ¡s al hombre, y llevado por su perversidad, lo colgÃ³ de un Ã¡rbol.
#
# ...

# %%
frecuenciaPalab=[]
for w in listaPalab

# %%
for w in listaPalabras:
    frecuenciaPalab.append(listaPalabras.count(w))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 2
#       1 for w in listaPalabras:
# ----> 2     frecuenciaPalab.append(listaPalabras.count(w))
#
# NameError: name 'frecuenciaPalab' is not defined

# %%
archi=open('Constitucion.txt','r')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 archi=open('Constitucion.txt','r')
#
# File ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Constitucion.txt'
