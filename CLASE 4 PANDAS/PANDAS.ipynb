# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
fruits=['apples','oranges', 'cherries', 'pears']

# %%
quantities=[20,32,44,56]

# %%
S=pd.Series(fruits,quantities)

# %%
S
# Out:
# 20      apples
# 32     oranges
# 44    cherries
# 56       pears
# dtype: object

# %%
##Dataframe

# %%
frutas_costa=["platano", "coco", "piña"]

# %%
frutas_sierra=["mandarina", "guaba", "chirimoya"]

# %%
index=["a","b","c"]

# %%
todas_las_frutas={"costa":frutas_costa,"sierra":frutas_sierra}

# %%
todas_las_frutas
# Out:
# {'costa': ['platano', 'coco', 'piña'],
#  'sierra': ['mandarina', 'guaba', 'chirimoya']}

# %%
frutas_indexadas=pd.DataFrame(todas_las_frutas)

# %%
frutas_indexadas
# Out:
#      costa     sierra
# 0  platano  mandarina
# 1     coco      guaba
# 2     piña  chirimoya

# %%
frutas_etiquetadas=pd.DataFrame(todas_las_frutas,index=index)

# %%
frutas_etiquetadas
# Out:
#      costa     sierra
# a  platano  mandarina
# b     coco      guaba
# c     piña  chirimoya

# %%
frutas_indexadas.to_csv('frutas.csv')

# %%
frutas_indexadas.to_json('frutas.json')

# %%
df=pd.read_csv('frutas.csv', index_col=0)

# %%
df
# Out:
#      costa     sierra
# 0  platano  mandarina
# 1     coco      guaba
# 2     piña  chirimoya

# %%
df2=pd.read_json('frutas.json')

# %%
df2
# Out:
#      costa     sierra
# 0  platano  mandarina
# 1     coco      guaba
# 2     piña  chirimoya

# %%
df3=pd.read_json('carros.json')

# %%
df3
# Out:
#                    auto1    auto2
# marca             Nissan   Toyota
# modelo          frontier  4runner
# anio                2020     2020
# cilindraje          4000     4000
# tipo_de_frenos     disco    disco

# %%
pip install pysqlite3
# Out:
# ...
#   Using cached pysqlite3-0.5.0.tar.gz (40 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Running setup.py clean for pysqlite3
# Failed to build pysqlite3
# ...
#   Running setup.py install for pysqlite3: started
#   Running setup.py install for pysqlite3: finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [18 lines of output]
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-cpython-310
#   creating build\lib.win-amd64-cpython-310\pysqlite3
#   copying pysqlite3\dbapi2.py -> build\lib.win-amd64-cpython-310\pysqlite3
#   copying pysqlite3\__init__.py -> build\lib.win-amd64-cpython-310\pysqlite3
#   running build_ext
#   Builds a C extension linking against libsqlite3 library
# ...

# %%
import sqlite3

# %%
con=sqlite3.connect("database.db")

# %%
df=pd.read_sql_query("SELECT * FROM compras",con)

# %%
df
# Out:
#    index  apples  oranges
# 0      2       6        7
# 1      3       8        9
# 2      1       5        7
# 3      4       7        8
# 4      7       6        5

# %%
con=sqlite3.connect("datos.db")

# %%
df1=pd.read_sql_query("SELECT * FROM canasta",con)

# %%
df1
# Out:
#       Jared Alejandro Panchito Alexis  Fernado  Miguel     Raul  Azucena  \
# 0     avena   lenteja    arroz   atun    avena   panes    arroz    avena
# 1     leche     avena    avena    sal    panes   leche  lenteja    panes
# 2     arroz   maicena     cafe  avena   fideos  huevos    leche   huevos
# 3    huevos        te   fideos  panes  maicena   avena    panes  lenteja
# 4  frijoles     panes    panes   cafe    arroz   arroz    avena    arroz
#
#    Camila   Kerly
# 0     sal   arroz
# 1  fideos      te
# 2   avena  huevos
# 3   panes    cafe
# 4    atun   avena

# %% [markdown]
# CARGAR ARCHIVOS CSV

# %%
movies_df=pd.read_csv("IMDB-Movie-Data.csv", index_col="Title")

# %%
movies_df
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
# ...                       ...                       ...
# Secret in Their Eyes      996       Crime,Drama,Mystery
# Hostel: Part II           997                    Horror
# Step Up 2: The Streets    998       Drama,Music,Romance
# Search Party              999          Adventure,Comedy
# Nine Lives               1000     Comedy,Family,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# ...

# %%
movies_df = pd.read_csv("https://raw.githubusercontent.com/LearnDataSci/articles/master/Python%20Pandas%20Tutorial%20A%20Complete%20Introduction%20for%20Beginners/IMDB-Movie-Data.csv", index_col="Title")

# %%
movies_df
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
# ...                       ...                       ...
# Secret in Their Eyes      996       Crime,Drama,Mystery
# Hostel: Part II           997                    Horror
# Step Up 2: The Streets    998       Drama,Music,Romance
# Search Party              999          Adventure,Comedy
# Nine Lives               1000     Comedy,Family,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# ...

# %%
movies_df.head()
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
# Sing                     In a city of humanoid animals, a hustling thea...
# Suicide Squad            A secret government agency recruits some of th...
#
#                                      Director  \
# Title
# Guardians of the Galaxy            James Gunn
# Prometheus                       Ridley Scott
# ...

# %%
movies_df.tail(2)
# Out:
#               Rank                  Genre  \
# Title
# Search Party   999       Adventure,Comedy
# Nine Lives    1000  Comedy,Family,Fantasy
#
#                                                     Description  \
# Title
# Search Party  A pair of friends embark on a mission to reuni...
# Nine Lives    A stuffy businessman finds himself trapped ins...
#
#                       Director  \
# Title
# Search Party    Scot Armstrong
# Nine Lives    Barry Sonnenfeld
#
#                                                          Actors  Year  \
# Title
# Search Party  Adam Pally, T.J. Miller, Thomas Middleditch,Sh...  2014
# Nine Lives    Kevin Spacey, Jennifer Garner, Robbie Amell,Ch...  2016
#
#               Runtime (Minutes)  Rating  Votes  Revenue (Millions)  Metascore
# Title
# Search Party                 93     5.6   4881                 NaN       22.0
# Nine Lives                   87     5.3  12435               19.64       11.0

# %%
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, Guardians of the Galaxy to Nine Lives
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Genre               1000 non-null   object
#  2   Description         1000 non-null   object
#  3   Director            1000 non-null   object
#  4   Actors              1000 non-null   object
#  5   Year                1000 non-null   int64
#  6   Runtime (Minutes)   1000 non-null   int64
#  7   Rating              1000 non-null   float64
#  8   Votes               1000 non-null   int64
#  9   Revenue (Millions)  872 non-null    float64
#  10  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(4)
# memory usage: 93.8+ KB

# %%
movies_df.shape
# Out:
# (1000, 11)

# %%
temp_df=movies_df.append(movies_df)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_21476\769481925.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_df=movies_df.append(movies_df)

# %%
temp_df
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
# ...                       ...                       ...
# Secret in Their Eyes      996       Crime,Drama,Mystery
# Hostel: Part II           997                    Horror
# Step Up 2: The Streets    998       Drama,Music,Romance
# Search Party              999          Adventure,Comedy
# Nine Lives               1000     Comedy,Family,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# ...

# %%
temp_df=pd.concat([movies_df, movies_df])

# %%
temp_df.shape
# Out:
# (2000, 11)

# %%
temp_df=temp_df.drop_duplicates()

# %%
movies_df = pd.read_csv("https://raw.githubusercontent.com/LearnDataSci/articles/master/Python%20Pandas%20Tutorial%20A%20Complete%20Introduction%20for%20Beginners/IMDB-Movie-Data.csv", index_col="Title")

# %%
movies_df.isnull().sum()
# Out:
# Rank                    0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
m2=movies_df.dropna()

# %%
m2
# Out:
#                           Rank                     Genre  \
# Title
# Guardians of the Galaxy      1   Action,Adventure,Sci-Fi
# Prometheus                   2  Adventure,Mystery,Sci-Fi
# Split                        3           Horror,Thriller
# Sing                         4   Animation,Comedy,Family
# Suicide Squad                5  Action,Adventure,Fantasy
# ...                        ...                       ...
# Resident Evil: Afterlife   994   Action,Adventure,Horror
# Project X                  995                    Comedy
# Hostel: Part II            997                    Horror
# Step Up 2: The Streets     998       Drama,Music,Romance
# Nine Lives                1000     Comedy,Family,Fantasy
#
#                                                                 Description  \
# Title
# Guardians of the Galaxy   A group of intergalactic criminals are forced ...
# Prometheus                Following clues to the origin of mankind, a te...
# ...

# %%
m2.isnull().sum()
# Out:
# Rank                  0
# Genre                 0
# Description           0
# Director              0
# Actors                0
# Year                  0
# Runtime (Minutes)     0
# Rating                0
# Votes                 0
# Revenue (Millions)    0
# Metascore             0
# dtype: int64

# %%
Metascore=movies_df['Metascore']

# %%
Metascore_mean=Metascore.mean()

# %%
Metascore_mean
# Out:
# 58.98504273504273

# %%
Metascore.fillna(Metascore_mean, inplace=True)

# %%
movies_df.isnull().sum()
# Out:
# Rank                    0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore               0
# dtype: int64

# %%
resultado=movies_df[movies_df['Rating']>= 8.5].value_counts().head(3)

# %%
resultado = pd.DataFrame(resultado)

# %%
resultado
# Out:
#                                                                                                                                                                                                                         0
# Rank Genre                  Description                                        Director          Actors                                             Year Runtime (Minutes) Rating Votes   Revenue (Millions) Metascore
# 37   Adventure,Drama,Sci-Fi A team of explorers travel through a wormhole i... Christopher Nolan Matthew McConaughey, Anne Hathaway, Jessica Cha... 2014 169               8.6    1047747 187.99             74.0       1
# 55   Action,Crime,Drama     When the menace known as the Joker wreaks havoc... Christopher Nolan Christian Bale, Heath Ledger, Aaron Eckhart,Mic... 2008 152               9.0    1791916 533.32             82.0       1
# ...

# %%
movies_df[(movies_df['Year']>=2010)&(movies_df['Year']<=2016)&(movies_df['Revenue (Millions)']>100)].head()
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
# Sing                     In a city of humanoid animals, a hustling thea...
# Suicide Squad            A secret government agency recruits some of th...
#
#                                      Director  \
# Title
# Guardians of the Galaxy            James Gunn
# Prometheus                       Ridley Scott
# ...

# %%
movies_df=pd.read_csv("Fornite.csv")

# %%
movies_df
# Out:
#         Rarity                    Weapon    DPS  Damage  Fire Rate  \
# 0       Common             Assault Rifle  165.0    30.0        5.5
# 1     Uncommon             Assault Rifle  170.5    31.0        5.5
# 2         Rare             Assault Rifle  181.5    33.0        5.5
# 3         Epic             Assault Rifle  192.5    35.0        5.5
# 4    Legendary             Assault Rifle  198.0    36.0        5.5
# ..         ...                       ...    ...     ...        ...
# 264       Epic  Mechanical Shockwave Bow   89.0    89.0        1.0
# 265  Legendary  Mechanical Shockwave Bow   94.0    94.0        1.0
# 266       Epic  Mechanical Explosive Bow   89.0    89.0        1.0
# 267  Legendary  Mechanical Explosive Bow   94.0    94.0        1.0
# 268     Common           Harvesting Tool   32.0    20.0        1.6
#
#      Magazine Size  Reload Time
# 0               30         2.52
# 1               30         2.41
# 2               30         2.30
# ...

# %%
movies_df[(movies_df['Weapon']=='Assault Rifle')]
# Out:
#       Rarity         Weapon    DPS  Damage  Fire Rate  Magazine Size  \
# 0     Common  Assault Rifle  165.0    30.0        5.5             30
# 1   Uncommon  Assault Rifle  170.5    31.0        5.5             30
# 2       Rare  Assault Rifle  181.5    33.0        5.5             30
# 3       Epic  Assault Rifle  192.5    35.0        5.5             30
# 4  Legendary  Assault Rifle  198.0    36.0        5.5             30
#
#    Reload Time
# 0         2.52
# 1         2.41
# 2         2.30
# 3         2.18
# 4         2.07

# %%
titanic=pd.read_csv("train-titanic.csv")

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic[(titanic['Age']>=32.0)&(titanic['Age']<=38.0)].head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 4             5         0       3
# 20           21         0       2
# 21           22         1       2
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 20                               Fynney, Mr. Joseph J    male  35.0      0
# 21                              Beesley, Mr. Lawrence    male  34.0      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 3       0    113803  53.1000  C123        S
# 4       0    373450   8.0500   NaN        S
# 20      0    239865  26.0000   NaN        S
# 21      0    248698  13.0000   D56        S

# %%
titanic[(titanic['Age']>=70.0)&(titanic['Survived']==1)].head()
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
#
#       Sex   Age  SibSp  Parch Ticket  Fare Cabin Embarked
# 630  male  80.0      0      0  27042  30.0   A23        S
